# %% [markdown]
# **EDA**
#
# Mobile Phone has a very wide range of features/specification and prices. Thus, make it difficult for mobile phone companies to set the right price for given features.
# Mobile phone companies also needs to know, the typical phone that the market is currently buying.
#
# Therefore, we need machine learning that are able to predict the right price for given features on the newcoming product
#
# **EDA Conclusion**
#
# Below are features of typical phone :
#
# - About half of them has bluetooth
# - About half are touch screen
# - About half are able to access wifi
# - About half of them are dual-sim
# - About 76% has 3G
# - About half of them has 4G
#
#
# - Median Battery power is 1226 mAH
# - Median talk-time battery is 11 hours
#
#
# - Median mobile depth is 0.5 cm
# - Median screen height is 12.0 cm
# - Median screen width is 5.0 cm
# - Median weight is 141 gram
#
#
# - Median primary camera is 10 Mega Pixels
# - Median front camera is 3.0 Mega Pixels
# - Median pixels resolution height is 564
# - Median pixels resolution width is 1247
#
#
# - Median internal memory is 32.0 Gigabytes
# - Median ram is 2146 Megabytes
# - Median n-cores is 4.0
# - Median clockspeed is 1.5

# %%
df.median()
# Out:
# battery_power    1226.0
# blue                0.0
# clock_speed         1.5
# dual_sim            1.0
# fc                  3.0
# four_g              1.0
# int_memory         32.0
# m_dep               0.5
# mobile_wt         141.0
# n_cores             4.0
# pc                 10.0
# px_height         564.0
# px_width         1247.0
# ram              2146.5
# sc_h               12.0
# sc_w                5.0
# talk_time          11.0
# three_g             1.0
# touch_screen        1.0
# wifi                1.0
# price_range         1.5
# dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv('mobile_price.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %% [markdown]
# **Checking Data Distribution and Outliers**

# %%
plt.figure(figsize=(16, 10))

plt.subplot(3,3,1)
sns.boxplot(df['battery_power'], color='lightgrey')

plt.subplot(3,3,2)
sns.boxplot(df['int_memory'], color='orange')

plt.subplot(3,3,3)
sns.boxplot(df['mobile_wt'], color='lightyellow')

plt.subplot(3,3,4)
sns.boxplot(df['px_height'], color='lightblue')

plt.subplot(3,3,5)
sns.boxplot(df['px_width'], color='lightgreen')

plt.subplot(3,3,6)
sns.boxplot(df['ram'], color='pink')

# %%
plt.figure(figsize=(16, 15))

plt.subplot(4,4,1)
sns.distplot(df['clock_speed'], color='brown')

plt.subplot(4,4,2)
sns.distplot(df['fc'], color='green')

plt.subplot(4,4,3)
sns.distplot(df['m_dep'], color='cyan')

plt.subplot(4,4,4)
sns.distplot(df['n_cores'], color='orange')

plt.subplot(4,4,5)
sns.distplot(df['pc'], color='blue')

plt.subplot(4,4,6)
sns.distplot(df['sc_h'], color='black')

plt.subplot(4,4,7)
sns.distplot(df['sc_w'], color='lime')

plt.subplot(4,4,8)
sns.distplot(df['talk_time'], color='red')

# %%
plt.figure(figsize=(16, 16))

plt.subplot(7,7,1)
labels = 'Yes', 'No'
colors = ['lightblue', 'white']
plt.pie(df['blue'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('equal')
plt.title('Bluetooth')

plt.subplot(7,7,2)
labels = 'Yes', 'No'
colors = ['lightgreen', 'white']
plt.pie(df['dual_sim'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('equal')
plt.title('Dual Sim')

plt.subplot(7,7,3)
labels = 'Yes', 'No'
colors = ['pink', 'white']
plt.pie(df['three_g'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('equal')
plt.title('3G')

plt.subplot(7,7,4)
labels = 'Yes', 'No'
colors = ['cyan', 'white']
plt.pie(df['four_g'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('equal')
plt.title('4G')

plt.subplot(7,7,5)
labels = 'Yes', 'No'
colors = ['brown', 'white']
plt.pie(df['touch_screen'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('equal')
plt.title('Touch Screen')

plt.subplot(7,7,6)
labels = 'Yes', 'No'
colors = ['lightgrey', 'white']
plt.pie(df['wifi'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('equal')
plt.title('wifi')

plt.subplot(7,7,7)
labels = 1,2,3,4
colors = ['lightgreen', 'lightblue', 'pink', 'lightyellow']
plt.pie(df['price_range'].value_counts(), labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=0)
plt.axis('equal')
plt.title('Price Class')

plt.show()

# %%
df.median()
# Out:
# battery_power    1226.0
# blue                0.0
# clock_speed         1.5
# dual_sim            1.0
# fc                  3.0
# four_g              1.0
# int_memory         32.0
# m_dep               0.5
# mobile_wt         141.0
# n_cores             4.0
# pc                 10.0
# px_height         564.0
# px_width         1247.0
# ram              2146.5
# sc_h               12.0
# sc_w                5.0
# talk_time          11.0
# three_g             1.0
# touch_screen        1.0
# wifi                1.0
# price_range         1.5
# dtype: float64
